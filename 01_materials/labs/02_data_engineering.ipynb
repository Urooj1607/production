# %%
# %load_ext dotenv
# %dotenv

# %%
import os
os.getenv('TICKERS')
# Out:
# '../../05_src/data/tickers/sp500_wiki.csv'

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss dask vs pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance and we will use the API provided by the library yfinance.
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# ![Medallion Architecture (DataBicks)](./images/02_medallion_architecture.png)
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class that will help us control the process of obtaining and transforming our data.
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# # Download Data from Yahoo Finance
#
# Yahoo Finance provides information about public stocks in different markets. The library yfinance gives us access to a fair bit of the data in Yahoo Finance.
#
# These steps are based on the instructions in:
#
# + [yfinance documentation](https://pypi.org/project/yfinance/)
# + [Tutorial in geeksforgeeks.org](https://www.geeksforgeeks.org/get-financial-data-from-yahoo-finance-with-python/)

# %% [markdown]
# + If required, install: `python -m pip install yfinance`.
# + To download the price history of a stock, first use the following setup:

# %%
import pandas as pd
import yfinance as yf
import os
import sys

sys.path.append(os.getenv('SRC_DIR'))

# %% [markdown]
# A few things to notice in the code chunk above:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager (pip in this case, but could be conda, poetry, etc.)
# + The command `sys.path.append("../05_src/)` will add the `../05_src/` directory to the path in the Notebook's kernel. This way, we can use our modules as part of the notebook.
# + Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by the documentation.

# %% [markdown]
# Now, to download the historical price data for a stock, we could use:

# %%
px = yf.download('AAPL', start = "2025-01-01", end = "2025-01-15")
px
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Adj Close       Close        High         Low  \
# Ticker                           AAPL        AAPL        AAPL        AAPL
# Date
# 2025-01-02 00:00:00+00:00  243.850006  243.850006  249.100006  241.820007
# 2025-01-03 00:00:00+00:00  243.360001  243.360001  244.179993  241.889999
# 2025-01-06 00:00:00+00:00  245.000000  245.000000  247.330002  243.199997
# 2025-01-07 00:00:00+00:00  242.210007  242.210007  245.550003  241.350006
# 2025-01-08 00:00:00+00:00  242.699997  242.699997  243.710007  240.050003
# 2025-01-10 00:00:00+00:00  236.850006  236.850006  240.160004  233.000000
# 2025-01-13 00:00:00+00:00  234.399994  234.399994  234.669998  229.720001
# 2025-01-14 00:00:00+00:00  233.279999  233.279999  236.119995  232.470001
#
# Price                            Open    Volume
# Ticker                           AAPL      AAPL
# Date
# 2025-01-02 00:00:00+00:00  248.929993  55740700
# 2025-01-03 00:00:00+00:00  243.360001  40244100
# 2025-01-06 00:00:00+00:00  244.309998  45045600
# 2025-01-07 00:00:00+00:00  242.979996  40856000
# 2025-01-08 00:00:00+00:00  241.919998  37628900
# 2025-01-10 00:00:00+00:00  240.009995  61710900
# 2025-01-13 00:00:00+00:00  233.529999  49630700
# 2025-01-14 00:00:00+00:00  234.750000  39435300

# %% [markdown]
# ## Parametrize the download
#
# + Generally, we will look to separate every parameter and setting from functions.
# + If we had a few stocks, we could cycle through them. We need a place to store the list of tickers (a db or file, for example).
# + Store a csv file with a few stock tickers. The location of the file is a setting, the contents of this file are parameters.
# + Use **environment variables** to pass parameters.
#
# Start by getting a sample of Information Technology stock tickers by applying subindexing and converting the "ticker" column from a pandas object to a list.

# %%
# Load all tickers
ticker_file = os.getenv("TICKERS")
tickers = pd.read_csv(ticker_file)

# %%
ticker_file = os.getenv("TICKERS")

# %%
tickers
# Out:
#     ticker              Security             GICS Sector  \
# 0      MMM                    3M             Industrials
# 1      AOS           A. O. Smith             Industrials
# 2      ABT                Abbott             Health Care
# 3     ABBV                AbbVie             Health Care
# 4      ACN             Accenture  Information Technology
# ..     ...                   ...                     ...
# 498    YUM           Yum! Brands  Consumer Discretionary
# 499   ZBRA    Zebra Technologies  Information Technology
# 500    ZBH         Zimmer Biomet             Health Care
# 501   ZION  Zions Bancorporation              Financials
# 502    ZTS                Zoetis             Health Care
#
#                       GICS Sub-Industry    Headquarters Location  Date added  \
# 0              Industrial Conglomerates    Saint Paul, Minnesota       20883
# 1                     Building Products     Milwaukee, Wisconsin       42942
# 2                 Health Care Equipment  North Chicago, Illinois       20883
# 3                         Biotechnology  North Chicago, Illinois       41274
# 4        IT Consulting & Other Services          Dublin, Ireland       40730
# ..                                  ...                      ...         ...
# 498                         Restaurants     Louisville, Kentucky       35709
# 499  Electronic Equipment & Instruments   Lincolnshire, Illinois       43822
# 500               Health Care Equipment          Warsaw, Indiana       37110
# 501                      Regional Banks     Salt Lake City, Utah       37064
# 502                     Pharmaceuticals   Parsippany, New Jersey       41446
#
#          CIK      Founded
# 0      66740         1902
# 1      91142         1916
# 2       1800         1888
# 3    1551152  2013 (1888)
# 4    1467373         1989
# ..       ...          ...
# 498  1041061         1997
# 499   877212         1969
# 500  1136869         1927
# 501   109380         1873
# 502  1555280         1952
#
# [503 rows x 8 columns]

# %% [markdown]
# We can subset our ticker data set using standard indexing techniques. A good reference for this type of data manipulation is Panda's [Documentation](https://pandas.pydata.org/docs/user_guide/indexing.html#indexing-and-selecting-data) and [Cookbook](https://pandas.pydata.org/docs/user_guide/cookbook.html#cookbook-selection).

# %%
idx_tech = tickers['GICS Sector'] == 'Information Technology'
tech_sector = tickers[idx_tech]
tech_sector
# Out:
#     ticker                Security             GICS Sector  \
# 4      ACN               Accenture  Information Technology
# 5     ADBE              Adobe Inc.  Information Technology
# 6      AMD  Advanced Micro Devices  Information Technology
# 12    AKAM                  Akamai  Information Technology
# 34     APH                Amphenol  Information Technology
# ..     ...                     ...                     ...
# 450   TRMB            Trimble Inc.  Information Technology
# 452    TYL      Tyler Technologies  Information Technology
# 467   VRSN                Verisign  Information Technology
# 488    WDC         Western Digital  Information Technology
# 499   ZBRA      Zebra Technologies  Information Technology
#
#                               GICS Sub-Industry     Headquarters Location  \
# 4                IT Consulting & Other Services           Dublin, Ireland
# 5                          Application Software      San Jose, California
# 6                                Semiconductors   Santa Clara, California
# 12           Internet Services & Infrastructure  Cambridge, Massachusetts
# 34                        Electronic Components  Wallingford, Connecticut
# ..                                          ...                       ...
# 450          Electronic Equipment & Instruments     Westminster, Colorado
# 452                        Application Software              Plano, Texas
# 467          Internet Services & Infrastructure          Dulles, Virginia
# 488  Technology Hardware, Storage & Peripherals      San Jose, California
# 499          Electronic Equipment & Instruments    Lincolnshire, Illinois
#
#      Date added      CIK Founded
# 4         40730  1467373    1989
# 5         35555   796343    1982
# 6         42814     2488    1969
# 12        39275  1086222    1998
# 34        39721   820313    1932
# ..          ...      ...     ...
# 450       44217   864749    1978
# 452       44004   860731    1966
# 467       38749  1014473    1995
# 488       39995   106040    1970
# 499       43822   877212    1969
#
# [64 rows x 8 columns]

# %% [markdown]
# From the subset data frame, select one column and convert to list.

# %%
tech_tickers = tech_sector['ticker'].to_list()

# %%
tech_raw_dt = yf.download(tech_tickers, start = "2000-01-01", end = "2025-01-26")
# Out:
# [*********************100%***********************]  64 of 64 completed

# %% [markdown]
# The data that we downloaded combines several stocks and prices into a single row. We want to parse this arrangement into a dataframe that contains observations about a single stock on a given day per row. To do this, we can use the function [`stack()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.stack.html) and re-arrange the indices.

# %%
# First, check what tech_raw_dt.stack() looks like.
tech_raw_dt.stack(future_stack=True).reset_index()
# Out:
# Price                       Date Ticker   Adj Close       Close        High  \
# 0      2000-01-03 00:00:00+00:00   AAPL    0.843076    0.999442    1.004464
# 1      2000-01-03 00:00:00+00:00    ACN         NaN         NaN         NaN
# 2      2000-01-03 00:00:00+00:00   ADBE   16.274673   16.390625   16.875000
# 3      2000-01-03 00:00:00+00:00    ADI   28.095697   45.093750   46.937500
# 4      2000-01-03 00:00:00+00:00   ADSK    8.052905    8.343750    8.656250
# ...                          ...    ...         ...         ...         ...
# 403451 2025-01-24 00:00:00+00:00    TXN  185.520004  185.520004  191.500000
# 403452 2025-01-24 00:00:00+00:00    TYL  591.929993  591.929993  594.969971
# 403453 2025-01-24 00:00:00+00:00   VRSN  210.729996  210.729996  210.880005
# 403454 2025-01-24 00:00:00+00:00    WDC   67.410004   67.410004   69.440002
# 403455 2025-01-24 00:00:00+00:00   ZBRA  414.609985  414.609985  420.079987
#
# Price          Low        Open       Volume
# 0         0.907924    0.936384  535796800.0
# 1              NaN         NaN          NaN
# 2        16.062500   16.812500    7384400.0
# 3        44.000000   46.750000    3655600.0
# 4         8.031250    8.500000    2845600.0
# ...            ...         ...          ...
# 403451  185.029999  190.000000   15856600.0
# 403452  590.210022  591.400024     155300.0
# 403453  206.009995  206.020004     563300.0
# 403454   67.360001   68.910004    6046500.0
# 403455  413.739990  419.059998     258900.0
#
# [403456 rows x 8 columns]

# %%
tech_dt = (tech_raw_dt
           .stack(future_stack=True)
           .reset_index()
           .sort_values(['Ticker', 'Date']))
tech_dt.columns.name = None

# %% [markdown]
# # Storing Data in CSV

# %% [markdown]
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parqruet, by measuring their performance:
#
#     - Time to save.
#     - Space required.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %%
import time

# %%
temp = os.getenv("TEMP_DATA")
os.makedirs(temp, exist_ok=True)
stock_path = os.path.join(temp, "stock_px.csv")

# %%
tech_dt.shape
# Out:
# (403456, 8)

# %%
start = time.time()
tech_dt.to_csv(stock_path, index = False)
end = time.time()

print(f'Writing to dt ({tech_dt.shape})csv took {end - start} seconds.')
print(f'Csv file size { os.path.getsize(stock_path)*1e-6 } MB')
# Out:
# Writing to dt ((403456, 8))csv took 5.801759481430054 seconds.
# Csv file size 47.817135 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Dask
#
# We can work with with large data sets and parquet files. In fact, recent versions of pandas support pyarrow data types and future versions will require a pyarrow backend. The pyarrow library is an interface between Python and the Appache Arrow project. The [parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are projects of the Apache Foundation.
#
# However, Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on pandas-like dataframes. It is also relatively easy to use, bridging a gap between pandas and Spark.

# %%
import dask.dataframe as dd
# Out:
# c:\Users\ufift\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\_pyarrow_compat.py:15: FutureWarning: Minimal version of pyarrow will soon be increased to 14.0.1. You are using 11.0.0. Please consider upgrading.
#   warnings.warn(

# %%
px_dd = dd.from_pandas(tech_dt, npartitions = len(tech_tickers))
parquet_path = os.path.join(temp, "stock_px.parquet")

start = time.time()
px_dd.to_parquet(parquet_path, engine = "pyarrow")
end = time.time()

print(f'Writing dd ({tech_dt.shape}) to parquet took {end - start} seconds.')
print(f'Parquet file size { get_dir_size(parquet_path)*1e-6 } MB')
# Out:
# Writing dd ((403456, 8)) to parquet took 1.4958958625793457 seconds.
# Parquet file size 16.595389 MB

# %% [markdown]
# ### Parquet files and Dask Dataframes
#
# + Parquet files are immutable: once written, they cannot be modified.
# + Dask DataFrames are a useful implementation to manipulate data stored in parquets.
# + Parquet and Dask are not the same: parquet is a file format that can be accessed by many applications and programming languages (Python, R, PowerBI, etc.), while Dask is a package in Python to work with large datasets using distributed computation.
# + **Dask is not for everything** (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
#
#     - Consider cases suchas small to large joins, where the small dataframe fits in memory, but the large one does not.
#     - If possible, use pandas: reduce, then use pandas.
#     - Pandas performance tips apply to Dask.
#     - Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
#     - Avoid (or minimize) full-data shuffling: indexing is an expensive operations.
#     - Some joins are more expensive than others.
#
#         * Not expensive:
#
#             - Join a Dask DataFrame with a pandas DataFrame.
#             - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#             - Join Dask DataFrames along their indexes.
#
#         * Expensive:
#
#             - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How do we store prices?
#
# + We can store our data as a single blob. This can be difficult to maintain, especially because parquet files are immutable.
# + Strategy: organize data files by ticker and date. Update only latest month.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
for ticker in tech_dt['Ticker'].unique():
    ticker_dt = tech_dt[tech_dt['Ticker'] == ticker]
    ticker_dt = ticker_dt.assign(Year = ticker_dt.Date.dt.year)
    for yr in ticker_dt['Year'].unique():
        yr_dd = dd.from_pandas(ticker_dt[ticker_dt['Year'] == yr],2)
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        yr_dd.to_parquet(yr_path, engine = "pyarrow")

# %% [markdown]
# Why would we want to store data this way?
#
# + Easier to maintain. We do not update old data, only recent data.
# + We can also access all files as follows.

# %% [markdown]
# # Load, Transform and Save

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to get the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "**/*.parquet"), recursive = True)
dd_px = dd.read_parquet(parquet_files).set_index("Ticker")

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work like pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.

# %%
dd_shift = dd_px.groupby('Ticker', group_keys=False).apply(
    lambda x: x.assign(Close_lag_1 = x['Close'].shift(1))
)
# Out:
# C:\Users\ufift\AppData\Local\Temp\ipykernel_11936\3086392435.py:1: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   dd_shift = dd_px.groupby('Ticker', group_keys=False).apply(

# %%
dd_rets = dd_shift.assign(
    Returns = lambda x: x['Close']/x['Close_lag_1'] - 1
)

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                                Date Adj Close    Close     High      Low     Open   Volume   Year Close_lag_1  Returns
# npartitions=64
# AAPL            datetime64[ns, UTC]   float64  float64  float64  float64  float64  float64  int32     float64  float64
# ACN                             ...       ...      ...      ...      ...      ...      ...    ...         ...      ...
# ...                             ...       ...      ...      ...      ...      ...      ...    ...         ...      ...
# ZBRA                            ...       ...      ...      ...      ...      ...      ...    ...         ...      ...
# ZBRA                            ...       ...      ...      ...      ...      ...      ...    ...         ...      ...
# Dask Name: assign, 9 expressions
# Expr=Assign(frame=Assign(frame=GroupByApply(frame=SetIndex(frame=ReadParquetFSSpec(c2b0f0d), _other='Ticker', options={}), observed=False, group_keys=False, func=<function <lambda> at 0x000001C4534B2F70>, meta=<no_default>, args=(), kwargs={})))

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until they are required.
# + To trigger an execution in dask use `.compute()`.

# %%
dd_rets.compute()
# Out:
#                             Date   Adj Close       Close        High  \
# Ticker
# AAPL   2000-01-03 00:00:00+00:00    0.843076    0.999442    1.004464
# AAPL   2000-01-04 00:00:00+00:00    0.771997    0.915179    0.987723
# AAPL   2000-01-05 00:00:00+00:00    0.783294    0.928571    0.987165
# AAPL   2000-01-06 00:00:00+00:00    0.715509    0.848214    0.955357
# AAPL   2000-01-07 00:00:00+00:00    0.749401    0.888393    0.901786
# ...                          ...         ...         ...         ...
# ZBRA   2025-01-17 00:00:00+00:00  405.709991  405.709991  407.290009
# ZBRA   2025-01-21 00:00:00+00:00  418.070007  418.070007  419.850006
# ZBRA   2025-01-22 00:00:00+00:00  420.570007  420.570007  427.760010
# ZBRA   2025-01-23 00:00:00+00:00  421.109985  421.109985  422.290009
# ZBRA   2025-01-24 00:00:00+00:00  414.609985  414.609985  420.079987
#
#                Low        Open       Volume  Year  Close_lag_1   Returns
# Ticker
# AAPL      0.907924    0.936384  535796800.0  2000          NaN       NaN
# AAPL      0.903460    0.966518  512377600.0  2000     0.999442 -0.084310
# AAPL      0.919643    0.926339  778321600.0  2000     0.915179  0.014633
# AAPL      0.848214    0.947545  767972800.0  2000     0.928571 -0.086538
# AAPL      0.852679    0.861607  460734400.0  2000     0.848214  0.047369
# ...            ...         ...          ...   ...          ...       ...
# ZBRA    402.290009  406.040009     270600.0  2025   402.720001  0.007424
# ZBRA    407.619995  407.619995     446000.0  2025   405.709991  0.030465
# ZBRA    419.589996  425.239990     497500.0  2025   418.070007  0.005980
# ZBRA    414.450012  417.619995     377100.0  2025   420.570007  0.001284
# ZBRA    413.739990  419.059998     258900.0  2025   421.109985 -0.015435
#
# [403456 rows x 10 columns]

# %% [markdown]
# ## Save
#
# + Apply transformations to calculate daily returns
# + Store the enriched data, the silver dataset, in a new directory.
# + Should we keep the same namespace? All columns?

# %%
# CLean up before save
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)
dd_rets.to_parquet(FEATURES_DATA, overwrite = True)

# %% [markdown]
# # Optional: from Jupyter to Command Line
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object Oriented vs Functional Programming
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefit from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# The `DataManager` class in `./05_src/data_manager.py` is a simple implementation of the ideas and code discussed in this notebook. The lines below will download data for about 500 stocks from the S&P500. Using this data a few features will be created and stored in the features data set.
#
# First, instantiate an object of class `DataManager`.

# %%
from data_manager import DataManager
dm = DataManager()

# %% [markdown]
# Download all prices.

# %%
dm.download_all()
# Out:
# 2025-01-31 12:21:43,141, data_manager.py, 42, INFO, Getting price data for all tickers.
# 2025-01-31 12:21:43,141, data_manager.py, 51, INFO, Getting tickers from ../../05_src/data/tickers/sp500_wiki.csv
# 2025-01-31 12:21:43,174, data_manager.py, 57, INFO, Processing all tickers
# 2025-01-31 12:21:43,175, data_manager.py, 70, INFO, Processing ticker ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADBE', 'AMD', 'AES', 'AFL', 'A', 'APD', 'ABNB', 'AKAM', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'ACGL', 'ADM', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'AXON', 'BKR', 'BALL', 'BAC', 'BK', 'BBWI', 'BAX', 'BDX', 'BRK.B', 'BBY', 'BIO', 'TECH', 'BIIB', 'BLK', 'BX', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'BF.B', 'BLDR', 'BG', 'CDNS', 'CZR', 'CPT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'COR', 'CNC', 'CNP', 'CF', 'CHRW', 'CRL', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'CEG', 'COO', 'CPRT', 'GLW', 'CTVA', 'CSGP', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 'CVS', 'DHR', 'DRI', 'DVA', 'DAY', 'DE', 'DAL', 'XRAY', 'DVN', 'DXCM', 'FANG', 'DLR', 'DFS', 'DG', 'DLTR', 'D', 'DPZ', 'DOV', 'DOW', 'DHI', 'DTE', 'DUK', 'DD', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'ELV', 'LLY', 'EMR', 'ENPH', 'ETR', 'EOG', 'EPAM', 'EQT', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'ETSY', 'EG', 'EVRG', 'ES', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'FDS', 'FICO', 'FAST', 'FRT', 'FDX', 'FIS', 'FITB', 'FSLR', 'FE', 'FI', 'FLT', 'FMC', 'F', 'FTNT', 'FTV', 'FOXA', 'FOX', 'BEN', 'FCX', 'GRMN', 'IT', 'GEHC', 'GEN', 'GNRC', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GPN', 'GL', 'GS', 'HAL', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HWM', 'HPQ', 'HUBB', 'HUM', 'HBAN', 'HII', 'IBM', 'IEX', 'IDXX', 'ITW', 'ILMN', 'INCY', 'IR', 'PODD', 'INTC', 'ICE', 'IFF', 'IP', 'IPG', 'INTU', 'ISRG', 'IVZ', 'INVH', 'IQV', 'IRM', 'JBHT', 'JBL', 'JKHY', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'KVUE', 'KDP', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KLAC', 'KHC', 'KR', 'LHX', 'LH', 'LRCX', 'LW', 'LVS', 'LDOS', 'LEN', 'LIN', 'LYV', 'LKQ', 'LMT', 'L', 'LOW', 'LULU', 'LYB', 'MTB', 'MRO', 'MPC', 'MKTX', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MTCH', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'MRNA', 'MHK', 'MOH', 'TAP', 'MDLZ', 'MPWR', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'NDAQ', 'NTAP', 'NFLX', 'NEM', 'NWSA', 'NWS', 'NEE', 'NKE', 'NI', 'NDSN', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'NVR', 'NXPI', 'ORLY', 'OXY', 'ODFL', 'OMC', 'ON', 'OKE', 'ORCL', 'OTIS', 'PCAR', 'PKG', 'PANW', 'PARA', 'PH', 'PAYX', 'PAYC', 'PYPL', 'PNR', 'PEP', 'PFE', 'PCG', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'POOL', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PTC', 'PSA', 'PHM', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RVTY', 'RHI', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 'STX', 'SRE', 'NOW', 'SHW', 'SPG', 'SWKS', 'SJM', 'SNA', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'STLD', 'STE', 'SYK', 'SYF', 'SNPS', 'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TRGP', 'TGT', 'TEL', 'TDY', 'TFX', 'TER', 'TSLA', 'TXN', 'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 'TRMB', 'TFC', 'TYL', 'TSN', 'USB', 'UBER', 'UDR', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VLTO', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VFC', 'VTRS', 'VICI', 'V', 'VMC', 'WRB', 'WAB', 'WBA', 'WMT', 'DIS', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WST', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'WTW', 'GWW', 'WYNN', 'XEL', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZION', 'ZTS']
# 2025-01-31 12:21:43,179, data_manager.py, 100, INFO, Getting stock price data for ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADBE', 'AMD', 'AES', 'AFL', 'A', 'APD', 'ABNB', 'AKAM', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'ACGL', 'ADM', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'AXON', 'BKR', 'BALL', 'BAC', 'BK', 'BBWI', 'BAX', 'BDX', 'BRK.B', 'BBY', 'BIO', 'TECH', 'BIIB', 'BLK', 'BX', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'BF.B', 'BLDR', 'BG', 'CDNS', 'CZR', 'CPT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'COR', 'CNC', 'CNP', 'CF', 'CHRW', 'CRL', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'CEG', 'COO', 'CPRT', 'GLW', 'CTVA', 'CSGP', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 'CVS', 'DHR', 'DRI', 'DVA', 'DAY', 'DE', 'DAL', 'XRAY', 'DVN', 'DXCM', 'FANG', 'DLR', 'DFS', 'DG', 'DLTR', 'D', 'DPZ', 'DOV', 'DOW', 'DHI', 'DTE', 'DUK', 'DD', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'ELV', 'LLY', 'EMR', 'ENPH', 'ETR', 'EOG', 'EPAM', 'EQT', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'ETSY', 'EG', 'EVRG', 'ES', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'FDS', 'FICO', 'FAST', 'FRT', 'FDX', 'FIS', 'FITB', 'FSLR', 'FE', 'FI', 'FLT', 'FMC', 'F', 'FTNT', 'FTV', 'FOXA', 'FOX', 'BEN', 'FCX', 'GRMN', 'IT', 'GEHC', 'GEN', 'GNRC', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GPN', 'GL', 'GS', 'HAL', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HWM', 'HPQ', 'HUBB', 'HUM', 'HBAN', 'HII', 'IBM', 'IEX', 'IDXX', 'ITW', 'ILMN', 'INCY', 'IR', 'PODD', 'INTC', 'ICE', 'IFF', 'IP', 'IPG', 'INTU', 'ISRG', 'IVZ', 'INVH', 'IQV', 'IRM', 'JBHT', 'JBL', 'JKHY', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'KVUE', 'KDP', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KLAC', 'KHC', 'KR', 'LHX', 'LH', 'LRCX', 'LW', 'LVS', 'LDOS', 'LEN', 'LIN', 'LYV', 'LKQ', 'LMT', 'L', 'LOW', 'LULU', 'LYB', 'MTB', 'MRO', 'MPC', 'MKTX', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MTCH', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'MRNA', 'MHK', 'MOH', 'TAP', 'MDLZ', 'MPWR', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'NDAQ', 'NTAP', 'NFLX', 'NEM', 'NWSA', 'NWS', 'NEE', 'NKE', 'NI', 'NDSN', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'NVR', 'NXPI', 'ORLY', 'OXY', 'ODFL', 'OMC', 'ON', 'OKE', 'ORCL', 'OTIS', 'PCAR', 'PKG', 'PANW', 'PARA', 'PH', 'PAYX', 'PAYC', 'PYPL', 'PNR', 'PEP', 'PFE', 'PCG', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'POOL', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PTC', 'PSA', 'PHM', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RVTY', 'RHI', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 'STX', 'SRE', 'NOW', 'SHW', 'SPG', 'SWKS', 'SJM', 'SNA', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'STLD', 'STE', 'SYK', 'SYF', 'SNPS', 'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TRGP', 'TGT', 'TEL', 'TDY', 'TFX', 'TER', 'TSLA', 'TXN', 'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 'TRMB', 'TFC', 'TYL', 'TSN', 'USB', 'UBER', 'UDR', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VLTO', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VFC', 'VTRS', 'VICI', 'V', 'VMC', 'WRB', 'WAB', 'WBA', 'WMT', 'DIS', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WST', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'WTW', 'GWW', 'WYNN', 'XEL', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZION', 'ZTS'] from 2000-01-01 to 2025-01-31
# [*********************100%***********************]  503 of 503 completed
#
# 8 Failed downloads:
# ['FLT', 'BRK.B', 'WRK', 'PXD', 'PEAK', 'MRO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# ['BF.B']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2000-01-01 -> 2025-01-31)')
# ['URI']: ChunkedEncodingError(ProtocolError('Connection broken: IncompleteRead(1 bytes read, 1 more expected)', IncompleteRead(1 bytes read, 1 more expected)))
# 2025-01-31 12:22:53,457, data_manager.py, 80, INFO, Saving data by year
# 2025-01-31 12:22:53,901, data_manager.py, 83, INFO, Saving data for A
# 2025-01-31 12:22:54,618, data_manager.py, 83, INFO, Saving data for AAL
# 2025-01-31 12:22:55,339, data_manager.py, 83, INFO, Saving data for AAPL
# 2025-01-31 12:22:56,068, data_manager.py, 83, INFO, Saving data for ABBV
# 2025-01-31 12:22:56,735, data_manager.py, 83, INFO, Saving data for ABNB
# 2025-01-31 12:22:57,425, data_manager.py, 83, INFO, Saving data for ABT
# 2025-01-31 12:22:58,155, data_manager.py, 83, INFO, Saving data for ACGL
# 2025-01-31 12:22:58,931, data_manager.py, 83, INFO, Saving data for ACN
# 2025-01-31 12:22:59,799, data_manager.py, 83, INFO, Saving data for ADBE
# 2025-01-31 12:23:00,665, data_manager.py, 83, INFO, Saving data for ADI
# 2025-01-31 12:23:01,451, data_manager.py, 83, INFO, Saving data for ADM
# 2025-01-31 12:23:02,232, data_manager.py, 83, INFO, Saving data for ADP
# 2025-01-31 12:23:03,050, data_manager.py, 83, INFO, Saving data for ADSK
# 2025-01-31 12:23:03,997, data_manager.py, 83, INFO, Saving data for AEE
# 2025-01-31 12:23:05,042, data_manager.py, 83, INFO, Saving data for AEP
# 2025-01-31 12:23:05,832, data_manager.py, 83, INFO, Saving data for AES
# 2025-01-31 12:23:06,595, data_manager.py, 83, INFO, Saving data for AFL
# 2025-01-31 12:23:07,399, data_manager.py, 83, INFO, Saving data for AIG
# 2025-01-31 12:23:08,170, data_manager.py, 83, INFO, Saving data for AIZ
# 2025-01-31 12:23:09,054, data_manager.py, 83, INFO, Saving data for AJG
# 2025-01-31 12:23:09,957, data_manager.py, 83, INFO, Saving data for AKAM
# 2025-01-31 12:23:10,799, data_manager.py, 83, INFO, Saving data for ALB
# 2025-01-31 12:23:11,651, data_manager.py, 83, INFO, Saving data for ALGN
# 2025-01-31 12:23:12,451, data_manager.py, 83, INFO, Saving data for ALL
# 2025-01-31 12:23:13,252, data_manager.py, 83, INFO, Saving data for ALLE
# 2025-01-31 12:23:14,028, data_manager.py, 83, INFO, Saving data for AMAT
# 2025-01-31 12:23:14,879, data_manager.py, 83, INFO, Saving data for AMCR
# 2025-01-31 12:23:15,751, data_manager.py, 83, INFO, Saving data for AMD
# 2025-01-31 12:23:16,679, data_manager.py, 83, INFO, Saving data for AME
# 2025-01-31 12:23:17,576, data_manager.py, 83, INFO, Saving data for AMGN
# 2025-01-31 12:23:18,500, data_manager.py, 83, INFO, Saving data for AMP
# 2025-01-31 12:23:19,479, data_manager.py, 83, INFO, Saving data for AMT
# 2025-01-31 12:23:20,411, data_manager.py, 83, INFO, Saving data for AMZN
# 2025-01-31 12:23:21,205, data_manager.py, 83, INFO, Saving data for ANET
# 2025-01-31 12:23:22,060, data_manager.py, 83, INFO, Saving data for ANSS
# 2025-01-31 12:23:22,954, data_manager.py, 83, INFO, Saving data for AON
# 2025-01-31 12:23:23,744, data_manager.py, 83, INFO, Saving data for AOS
# 2025-01-31 12:23:24,574, data_manager.py, 83, INFO, Saving data for APA
# 2025-01-31 12:23:25,275, data_manager.py, 83, INFO, Saving data for APD
# 2025-01-31 12:23:25,941, data_manager.py, 83, INFO, Saving data for APH
# 2025-01-31 12:23:26,621, data_manager.py, 83, INFO, Saving data for APTV
# 2025-01-31 12:23:27,331, data_manager.py, 83, INFO, Saving data for ARE
# 2025-01-31 12:23:28,056, data_manager.py, 83, INFO, Saving data for ATO
# 2025-01-31 12:23:28,875, data_manager.py, 83, INFO, Saving data for AVB
# 2025-01-31 12:23:29,675, data_manager.py, 83, INFO, Saving data for AVGO
# 2025-01-31 12:23:30,474, data_manager.py, 83, INFO, Saving data for AVY
# 2025-01-31 12:23:31,378, data_manager.py, 83, INFO, Saving data for AWK
# 2025-01-31 12:23:32,173, data_manager.py, 83, INFO, Saving data for AXON
# 2025-01-31 12:23:32,956, data_manager.py, 83, INFO, Saving data for AXP
# 2025-01-31 12:23:33,723, data_manager.py, 83, INFO, Saving data for AZO
# 2025-01-31 12:23:34,574, data_manager.py, 83, INFO, Saving data for BA
# 2025-01-31 12:23:35,421, data_manager.py, 83, INFO, Saving data for BAC
# 2025-01-31 12:23:36,252, data_manager.py, 83, INFO, Saving data for BALL
# 2025-01-31 12:23:37,019, data_manager.py, 83, INFO, Saving data for BAX
# 2025-01-31 12:23:37,864, data_manager.py, 83, INFO, Saving data for BBWI
# 2025-01-31 12:23:38,668, data_manager.py, 83, INFO, Saving data for BBY
# 2025-01-31 12:23:39,510, data_manager.py, 83, INFO, Saving data for BDX
# 2025-01-31 12:23:40,303, data_manager.py, 83, INFO, Saving data for BEN
# 2025-01-31 12:23:41,101, data_manager.py, 83, INFO, Saving data for BF.B
# 2025-01-31 12:23:41,935, data_manager.py, 83, INFO, Saving data for BG
# 2025-01-31 12:23:42,716, data_manager.py, 83, INFO, Saving data for BIIB
# 2025-01-31 12:23:43,601, data_manager.py, 83, INFO, Saving data for BIO
# 2025-01-31 12:23:44,384, data_manager.py, 83, INFO, Saving data for BK
# 2025-01-31 12:23:45,203, data_manager.py, 83, INFO, Saving data for BKNG
# 2025-01-31 12:23:46,083, data_manager.py, 83, INFO, Saving data for BKR
# 2025-01-31 12:23:46,997, data_manager.py, 83, INFO, Saving data for BLDR
# 2025-01-31 12:23:47,982, data_manager.py, 83, INFO, Saving data for BLK
# 2025-01-31 12:23:48,894, data_manager.py, 83, INFO, Saving data for BMY
# 2025-01-31 12:23:49,784, data_manager.py, 83, INFO, Saving data for BR
# 2025-01-31 12:23:50,764, data_manager.py, 83, INFO, Saving data for BRK.B
# 2025-01-31 12:23:51,631, data_manager.py, 83, INFO, Saving data for BRO
# 2025-01-31 12:23:52,453, data_manager.py, 83, INFO, Saving data for BSX
# 2025-01-31 12:23:53,248, data_manager.py, 83, INFO, Saving data for BWA
# 2025-01-31 12:23:54,053, data_manager.py, 83, INFO, Saving data for BX
# 2025-01-31 12:23:54,796, data_manager.py, 83, INFO, Saving data for BXP
# 2025-01-31 12:23:55,479, data_manager.py, 83, INFO, Saving data for C
# 2025-01-31 12:23:56,129, data_manager.py, 83, INFO, Saving data for CAG
# 2025-01-31 12:23:56,780, data_manager.py, 83, INFO, Saving data for CAH
# 2025-01-31 12:23:57,452, data_manager.py, 83, INFO, Saving data for CARR
# 2025-01-31 12:23:58,179, data_manager.py, 83, INFO, Saving data for CAT
# 2025-01-31 12:23:59,014, data_manager.py, 83, INFO, Saving data for CB
# 2025-01-31 12:23:59,795, data_manager.py, 83, INFO, Saving data for CBOE
# 2025-01-31 12:24:00,600, data_manager.py, 83, INFO, Saving data for CBRE
# 2025-01-31 12:24:01,389, data_manager.py, 83, INFO, Saving data for CCI
# 2025-01-31 12:24:02,188, data_manager.py, 83, INFO, Saving data for CCL
# 2025-01-31 12:24:02,979, data_manager.py, 83, INFO, Saving data for CDNS
# 2025-01-31 12:24:03,793, data_manager.py, 83, INFO, Saving data for CDW
# 2025-01-31 12:24:04,712, data_manager.py, 83, INFO, Saving data for CE
# 2025-01-31 12:24:05,554, data_manager.py, 83, INFO, Saving data for CEG
# 2025-01-31 12:24:06,346, data_manager.py, 83, INFO, Saving data for CF
# 2025-01-31 12:24:07,143, data_manager.py, 83, INFO, Saving data for CFG
# 2025-01-31 12:24:07,927, data_manager.py, 83, INFO, Saving data for CHD
# 2025-01-31 12:24:08,754, data_manager.py, 83, INFO, Saving data for CHRW
# 2025-01-31 12:24:09,539, data_manager.py, 83, INFO, Saving data for CHTR
# 2025-01-31 12:24:10,378, data_manager.py, 83, INFO, Saving data for CI
# 2025-01-31 12:24:11,227, data_manager.py, 83, INFO, Saving data for CINF
# 2025-01-31 12:24:12,081, data_manager.py, 83, INFO, Saving data for CL
# 2025-01-31 12:24:12,860, data_manager.py, 83, INFO, Saving data for CLX
# 2025-01-31 12:24:13,656, data_manager.py, 83, INFO, Saving data for CMA
# 2025-01-31 12:24:14,440, data_manager.py, 83, INFO, Saving data for CMCSA
# 2025-01-31 12:24:15,290, data_manager.py, 83, INFO, Saving data for CME
# 2025-01-31 12:24:16,212, data_manager.py, 83, INFO, Saving data for CMG
# 2025-01-31 12:24:17,089, data_manager.py, 83, INFO, Saving data for CMI
# 2025-01-31 12:24:18,259, data_manager.py, 83, INFO, Saving data for CMS
# 2025-01-31 12:24:19,437, data_manager.py, 83, INFO, Saving data for CNC
# 2025-01-31 12:24:20,463, data_manager.py, 83, INFO, Saving data for CNP
# 2025-01-31 12:24:21,374, data_manager.py, 83, INFO, Saving data for COF
# 2025-01-31 12:24:22,292, data_manager.py, 83, INFO, Saving data for COO
# 2025-01-31 12:24:23,197, data_manager.py, 83, INFO, Saving data for COP
# 2025-01-31 12:24:24,083, data_manager.py, 83, INFO, Saving data for COR
# 2025-01-31 12:24:24,950, data_manager.py, 83, INFO, Saving data for COST
# 2025-01-31 12:24:25,672, data_manager.py, 83, INFO, Saving data for CPB
# 2025-01-31 12:24:26,534, data_manager.py, 83, INFO, Saving data for CPRT
# 2025-01-31 12:24:27,372, data_manager.py, 83, INFO, Saving data for CPT
# 2025-01-31 12:24:28,274, data_manager.py, 83, INFO, Saving data for CRL
# 2025-01-31 12:24:29,197, data_manager.py, 83, INFO, Saving data for CRM
# 2025-01-31 12:24:30,170, data_manager.py, 83, INFO, Saving data for CSCO
# 2025-01-31 12:24:31,211, data_manager.py, 83, INFO, Saving data for CSGP
# 2025-01-31 12:24:32,100, data_manager.py, 83, INFO, Saving data for CSX
# 2025-01-31 12:24:33,021, data_manager.py, 83, INFO, Saving data for CTAS
# 2025-01-31 12:24:34,015, data_manager.py, 83, INFO, Saving data for CTLT
# 2025-01-31 12:24:35,023, data_manager.py, 83, INFO, Saving data for CTRA
# 2025-01-31 12:24:36,035, data_manager.py, 83, INFO, Saving data for CTSH
# 2025-01-31 12:24:36,976, data_manager.py, 83, INFO, Saving data for CTVA
# 2025-01-31 12:24:37,950, data_manager.py, 83, INFO, Saving data for CVS
# 2025-01-31 12:24:38,930, data_manager.py, 83, INFO, Saving data for CVX
# 2025-01-31 12:24:39,831, data_manager.py, 83, INFO, Saving data for CZR
# 2025-01-31 12:24:40,697, data_manager.py, 83, INFO, Saving data for D
# 2025-01-31 12:24:41,569, data_manager.py, 83, INFO, Saving data for DAL
# 2025-01-31 12:24:42,483, data_manager.py, 83, INFO, Saving data for DAY
# 2025-01-31 12:24:43,372, data_manager.py, 83, INFO, Saving data for DD
# 2025-01-31 12:24:44,250, data_manager.py, 83, INFO, Saving data for DE
# 2025-01-31 12:24:45,139, data_manager.py, 83, INFO, Saving data for DFS
# 2025-01-31 12:24:46,149, data_manager.py, 83, INFO, Saving data for DG
# 2025-01-31 12:24:47,145, data_manager.py, 83, INFO, Saving data for DGX
# 2025-01-31 12:24:48,219, data_manager.py, 83, INFO, Saving data for DHI
# 2025-01-31 12:24:49,511, data_manager.py, 83, INFO, Saving data for DHR
# 2025-01-31 12:24:50,436, data_manager.py, 83, INFO, Saving data for DIS
# 2025-01-31 12:24:51,327, data_manager.py, 83, INFO, Saving data for DLR
# 2025-01-31 12:24:52,344, data_manager.py, 83, INFO, Saving data for DLTR
# 2025-01-31 12:24:53,293, data_manager.py, 83, INFO, Saving data for DOV
# 2025-01-31 12:24:54,202, data_manager.py, 83, INFO, Saving data for DOW
# 2025-01-31 12:24:55,058, data_manager.py, 83, INFO, Saving data for DPZ
# 2025-01-31 12:24:55,844, data_manager.py, 83, INFO, Saving data for DRI
# 2025-01-31 12:24:56,608, data_manager.py, 83, INFO, Saving data for DTE
# 2025-01-31 12:24:57,390, data_manager.py, 83, INFO, Saving data for DUK
# 2025-01-31 12:24:58,255, data_manager.py, 83, INFO, Saving data for DVA
# 2025-01-31 12:24:59,143, data_manager.py, 83, INFO, Saving data for DVN
# 2025-01-31 12:25:00,221, data_manager.py, 83, INFO, Saving data for DXCM
# 2025-01-31 12:25:01,296, data_manager.py, 83, INFO, Saving data for EA
# 2025-01-31 12:25:02,265, data_manager.py, 83, INFO, Saving data for EBAY
# 2025-01-31 12:25:03,201, data_manager.py, 83, INFO, Saving data for ECL
# 2025-01-31 12:25:04,176, data_manager.py, 83, INFO, Saving data for ED
# 2025-01-31 12:25:05,354, data_manager.py, 83, INFO, Saving data for EFX
# 2025-01-31 12:25:06,313, data_manager.py, 83, INFO, Saving data for EG
# 2025-01-31 12:25:07,413, data_manager.py, 83, INFO, Saving data for EIX
# 2025-01-31 12:25:08,644, data_manager.py, 83, INFO, Saving data for EL
# 2025-01-31 12:25:09,721, data_manager.py, 83, INFO, Saving data for ELV
# 2025-01-31 12:25:10,637, data_manager.py, 83, INFO, Saving data for EMN
# 2025-01-31 12:25:11,798, data_manager.py, 83, INFO, Saving data for EMR
# 2025-01-31 12:25:13,145, data_manager.py, 83, INFO, Saving data for ENPH
# 2025-01-31 12:25:14,777, data_manager.py, 83, INFO, Saving data for EOG
# 2025-01-31 12:25:15,959, data_manager.py, 83, INFO, Saving data for EPAM
# 2025-01-31 12:25:17,341, data_manager.py, 83, INFO, Saving data for EQIX
# 2025-01-31 12:25:18,949, data_manager.py, 83, INFO, Saving data for EQR
# 2025-01-31 12:25:20,571, data_manager.py, 83, INFO, Saving data for EQT
# 2025-01-31 12:25:22,142, data_manager.py, 83, INFO, Saving data for ES
# 2025-01-31 12:25:23,815, data_manager.py, 83, INFO, Saving data for ESS
# 2025-01-31 12:25:24,952, data_manager.py, 83, INFO, Saving data for ETN
# 2025-01-31 12:25:25,854, data_manager.py, 83, INFO, Saving data for ETR
# 2025-01-31 12:25:27,140, data_manager.py, 83, INFO, Saving data for ETSY
# 2025-01-31 12:25:28,502, data_manager.py, 83, INFO, Saving data for EVRG
# 2025-01-31 12:25:29,756, data_manager.py, 83, INFO, Saving data for EW
# 2025-01-31 12:25:31,103, data_manager.py, 83, INFO, Saving data for EXC
# 2025-01-31 12:25:32,431, data_manager.py, 83, INFO, Saving data for EXPD
# 2025-01-31 12:25:33,450, data_manager.py, 83, INFO, Saving data for EXPE
# 2025-01-31 12:25:34,464, data_manager.py, 83, INFO, Saving data for EXR
# 2025-01-31 12:25:35,716, data_manager.py, 83, INFO, Saving data for F
# 2025-01-31 12:25:36,801, data_manager.py, 83, INFO, Saving data for FANG
# 2025-01-31 12:25:37,903, data_manager.py, 83, INFO, Saving data for FAST
# 2025-01-31 12:25:39,188, data_manager.py, 83, INFO, Saving data for FCX
# 2025-01-31 12:25:40,528, data_manager.py, 83, INFO, Saving data for FDS
# 2025-01-31 12:25:42,079, data_manager.py, 83, INFO, Saving data for FDX
# 2025-01-31 12:25:43,624, data_manager.py, 83, INFO, Saving data for FE
# 2025-01-31 12:25:45,295, data_manager.py, 83, INFO, Saving data for FFIV
# 2025-01-31 12:25:46,821, data_manager.py, 83, INFO, Saving data for FI
# 2025-01-31 12:25:48,427, data_manager.py, 83, INFO, Saving data for FICO
# 2025-01-31 12:25:49,824, data_manager.py, 83, INFO, Saving data for FIS
# 2025-01-31 12:25:51,142, data_manager.py, 83, INFO, Saving data for FITB
# 2025-01-31 12:25:52,497, data_manager.py, 83, INFO, Saving data for FLT
# 2025-01-31 12:25:53,996, data_manager.py, 83, INFO, Saving data for FMC
# 2025-01-31 12:25:55,358, data_manager.py, 83, INFO, Saving data for FOX
# 2025-01-31 12:25:56,557, data_manager.py, 83, INFO, Saving data for FOXA
# 2025-01-31 12:25:57,966, data_manager.py, 83, INFO, Saving data for FRT
# 2025-01-31 12:25:59,080, data_manager.py, 83, INFO, Saving data for FSLR
# 2025-01-31 12:26:00,408, data_manager.py, 83, INFO, Saving data for FTNT
# 2025-01-31 12:26:01,923, data_manager.py, 83, INFO, Saving data for FTV
# 2025-01-31 12:26:03,296, data_manager.py, 83, INFO, Saving data for GD
# 2025-01-31 12:26:04,465, data_manager.py, 83, INFO, Saving data for GE
# 2025-01-31 12:26:05,455, data_manager.py, 83, INFO, Saving data for GEHC
# 2025-01-31 12:26:06,484, data_manager.py, 83, INFO, Saving data for GEN
# 2025-01-31 12:26:07,715, data_manager.py, 83, INFO, Saving data for GILD
# 2025-01-31 12:26:08,601, data_manager.py, 83, INFO, Saving data for GIS
# 2025-01-31 12:26:09,690, data_manager.py, 83, INFO, Saving data for GL
# 2025-01-31 12:26:10,906, data_manager.py, 83, INFO, Saving data for GLW
# 2025-01-31 12:26:12,514, data_manager.py, 83, INFO, Saving data for GM
# 2025-01-31 12:26:13,943, data_manager.py, 83, INFO, Saving data for GNRC
# 2025-01-31 12:26:15,670, data_manager.py, 83, INFO, Saving data for GOOG
# 2025-01-31 12:26:17,151, data_manager.py, 83, INFO, Saving data for GOOGL
# 2025-01-31 12:26:18,521, data_manager.py, 83, INFO, Saving data for GPC
# 2025-01-31 12:26:19,947, data_manager.py, 83, INFO, Saving data for GPN
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 dm.download_all()
#
# File c:\Users\ufift\production\01_materials\labs\../../05_src\data_manager.py:44, in DataManager.download_all(self)
#      42 _logs.info(f'Getting price data for all tickers.')
#      43 self.get_tickers()
# ---> 44 self.process_all_tickers()
#
# File c:\Users\ufift\production\01_materials\labs\../../05_src\data_manager.py:59, in DataManager.process_all_tickers(self)
#      57 _logs.info(f'Processing all tickers')
#      58 ticker_list = self.tickers['ticker'].unique().tolist()
# ---> 59 self.get_data_and_save_by_year(ticker_list,
#      60                                 self.start_date,
#      61                                 self.end_date,
#      62                                 self.price_dir)
#
# File c:\Users\ufift\production\01_materials\labs\../../05_src\data_manager.py:73, in DataManager.get_data_and_save_by_year(tickers, start_date, end_date, outpath, sector, subsector)
#      71 ticker_dt = DataManager.get_stock_price_data(tickers, start_date, end_date)
#      72 _logs.debug(f'ticker_dt columns {ticker_dt.columns}')
# ---> 73 DataManager.save_by_year(ticker_dt, outpath)
#
# File c:\Users\ufift\production\01_materials\labs\../../05_src\data_manager.py:85, in DataManager.save_by_year(ticker_dt, outpath)
#      83 _logs.info(f'Saving data for {ticker}')
#      84 os.makedirs(os.path.join(outpath, ticker), exist_ok = True)
# ---> 85 t_dt = ticker_dt[ticker_dt['Ticker'] == ticker]
#      86 for yr in t_dt['Year'].unique():
#      87     yr_dd = (dd
#      88              .from_pandas(t_dt[t_dt['Year'] == yr], npartitions=1)
#      89              .set_index('Ticker'))
#
# File c:\Users\ufift\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\ufift\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File c:\Users\ufift\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
#    6117 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6119 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6121 return self._construct_result(res_values, name=res_name)
#
# File c:\Users\ufift\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\ops\array_ops.py:344, in comparison_op(left, right, op)
#     341     return invalid_comparison(lvalues, rvalues, op)
#     343 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 344     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     346 else:
#     347     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File c:\Users\ufift\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\ops\array_ops.py:130, in comp_method_OBJECT_ARRAY(op, x, y)
#     128 else:
#     129     result = libops.scalar_compare(x.ravel(), y, op)
# --> 130 return result.reshape(x.shape)
#
# KeyboardInterrupt:

# %% [markdown]
# Finally, add features to the data set and save to a *feature store*.

# %%
dm.featurize()
